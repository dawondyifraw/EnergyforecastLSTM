# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../raw/PJME_hourly.csv", index_col=["Datetime"], parse_dates=["Datetime"])

# %%
df.head()
# Out:
#                      PJME_MW
# Datetime
# 2002-12-31 01:00:00  26498.0
# 2002-12-31 02:00:00  25147.0
# 2002-12-31 03:00:00  24574.0
# 2002-12-31 04:00:00  24393.0
# 2002-12-31 05:00:00  24860.0

# %%
df.describe()
# Out:
#              PJME_MW
# count  145366.000000
# mean    32080.222831
# std      6464.012166
# min     14544.000000
# 25%     27573.000000
# 50%     31421.000000
# 75%     35650.000000
# max     62009.000000

# %%
print(df.info())
print(df.describe())
print("Shape",df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145366 entries, 2002-12-31 01:00:00 to 2018-01-02 00:00:00
# Data columns (total 1 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   PJME_MW  145366 non-null  float64
# dtypes: float64(1)
# memory usage: 2.2 MB
# None
#              PJME_MW
# count  145366.000000
# mean    32080.222831
# std      6464.012166
# min     14544.000000
# 25%     27573.000000
# 50%     31421.000000
# 75%     35650.000000
# max     62009.000000
# Shape (145366, 1)

# %%
df.rename(columns={"PJME_MW": "load"}, inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                         load
# Datetime
# 2002-01-01 01:00:00  30393.0
# 2002-01-01 02:00:00  29265.0
# 2002-01-01 03:00:00  28357.0
# 2002-01-01 04:00:00  27899.0
# 2002-01-01 05:00:00  28057.0

# %%
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('retina')

# %%
plt.figure(figsize=(15, 5))
plt.plot(df.index, df["load"])
plt.title("PJME Hourly Load Data")
plt.xlabel("Datetime")
plt.ylabel("Load (MW)")
plt.show()

# %%
print(df.isnull().sum())
print(df.index.duplicated().any()) 
np.True_
print(df.index.min(), df.index.max())
# Out:
# load    0
# dtype: int64
# True
# 2002-01-01 01:00:00 2018-08-03 00:00:00

# %%
df = df.loc[~df.index.duplicated(keep='first')]

# %%
df["load"].resample('D').mean().plot()
plt.show()

# %%
df["load"].resample('YE').mean().plot()
plt.show()

# %%
df["load"].resample('M').mean().plot()
plt.show()
# Out:
# /tmp/ipykernel_217316/1352935677.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df["load"].resample('M').mean().plot()

# %%
df["load"].resample('W').mean().plot()
plt.show()

# %%
df.to_csv("transformed_load.csv",index=True)
